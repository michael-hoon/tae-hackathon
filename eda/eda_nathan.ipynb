# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_train = pd.read_csv("data//test2024.csv")
# display(df_train)
features = list(df_train.columns)
features.sort()

car_features = ['Price1','Price2','Price3','Price4', 'AF1','AF2','AF3','AF4','BU1','BU2','BU3','BU4','BZ1','BZ2','BZ3','BZ4','CC1','CC2','CC3','CC4', 'FA1','FA2','FA3','FA4','FC1','FC2','FC3','FC4','FP1','FP2','FP3','FP4','GN1','GN2','GN3','GN4','HU1','HU2','HU3','HU4','KA1','KA2','KA3','KA4','LB1','LB2','LB3','LB4','LD1','LD2','LD3','LD4','MA1','MA2','MA3','MA4','NS1','NS2','NS3','NS4','NV1','NV2','NV3','NV4','PP1','PP2','PP3','PP4','RP1','RP2','RP3','RP4','SC1','SC2','SC3','SC4','TS1','TS2','TS3','TS4']
unique_attributes = ["AF", "BU", "BZ", "CC", "FA", "FC", "FP", "GN", "HU", "KA", "LB", "LD", "MA", "NS", "NV", "PP", "RP", "SC", "TS"]
respondent_features = ['Urb','Urbind','age','agea','ageind','educ','educind','gender','genderind','income','incomea','incomeind','miles','milesa','milesind','night','nighta','nightind','ppark','pparkind','region','regionind','segment','segmentind','year','yearind']
display(df_train[respondent_features])
display(df_train[['ppark','pparkind','region','regionind','segment','segmentind','year','yearind']])



# # respondent_feature = respondent_features[2]
# respondent_feature = 'Price2'
# for car_feature in car_features: 
#     myplot = sns.scatterplot(y=car_feature, x=respondent_feature, hue='Price1', data=df_train)
#     # myplot.set_xlabel('Count', fontsize=16)
#     # myplot.set_ylabel('Resale Price in $1000', fontsize=16)
#     myplot.set_title(f'Histogram of {car_feature}', fontsize=16)

#     # plt.figure(figsize=(8, 6))
#     # plt.title(f'Histogram of {feature}', weight='bold')
#     # sns.histplot(x=feature, data=df_train, bins=300)
#     # # plt.xlabel('')
#     # # plt.ylabel('')
    
#     plt.show()
# Out:
#                 Urb  Urbind       age  agea  ageind  \
# 0     Rural/Country       1  Under 30    23       1
# 1     Rural/Country       1  Under 30    23       1
# 2     Rural/Country       1  Under 30    23       1
# 3     Rural/Country       1  Under 30    23       1
# 4     Rural/Country       1  Under 30    23       1
# ...             ...     ...       ...   ...     ...
# 4992     Urban/City       3  40 To 49    42       3
# 4993     Urban/City       3  40 To 49    42       3
# 4994     Urban/City       3  40 To 49    42       3
# 4995     Urban/City       3  40 To 49    42       3
# 4996     Urban/City       3  40 To 49    42       3
#
#                             educ  educind  gender  genderind  \
# 0     College Graduate (4 Years)        1    Male          2
# 1     College Graduate (4 Years)        1    Male          2
# 2     College Graduate (4 Years)        1    Male          2
# 3     College Graduate (4 Years)        1    Male          2
# ...

# %%
df_train.describe()
# Out:
#               Case            No         Task          CC1          GN1  \
# count  4997.000000   4997.000000  4997.000000  4997.000000  4997.000000
# mean   1267.000000  24064.000000    10.000000     0.942365     0.709426
# std      75.928609   1442.653978     5.477774     1.144958     0.823261
# min    1136.000000  21566.000000     1.000000     0.000000     0.000000
# 25%    1201.000000  22815.000000     5.000000     0.000000     0.000000
# 50%    1267.000000  24064.000000    10.000000     0.000000     0.000000
# 75%    1333.000000  25313.000000    15.000000     2.000000     1.000000
# max    1398.000000  26562.000000    19.000000     3.000000     2.000000
#
#                NS1          BU1          FA1          LD1          BZ1  ...  \
# count  4997.000000  4997.000000  4997.000000  4997.000000  4997.000000  ...
# mean      1.408845     1.648389     0.715229     0.944767     0.935962  ...
# std       1.779573     2.106132     0.828555     1.145251     1.134783  ...
# ...

# %%
for idx, row in df_train.iterrows(): 
    print(row['Ch1'])
    if row['Ch1'] == 1: 
        choice = 1
    elif row['Ch2'] == 1: 
        choice = 2
    elif row['Ch3'] == 1: 
        choice = 3
    else: 
        choice = 4

    df_train.at[idx, 'Choice'] = choice
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %%
sns.stripplot(x="Choice", y="Task", data=df_train, hue="gender", legend=False)
# Out:
# c:\Users\natha\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Choice', ylabel='Task'>

# %%
myplot = sns.pairplot(data=df_train[['Urbind', 'agea', 'educind', 'genderind', 'gender', 'incomea', 'milesa', 'nighta', 'pparkind', 'regionind', 'segmentind', 'year']], corner=True, hue='gender', diag_kind="hist")
plt.show()
# Out:
# c:\Users\natha\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\natha\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\natha\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...
